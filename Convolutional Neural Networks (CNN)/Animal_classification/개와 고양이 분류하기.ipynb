# %%
import os 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import rlcompleter, readline
readline.parse_and_bind('tab:complete')

# %%
filenames = os.listdir('C:/Users/Lee Jong Ann/Desktop/dataset/CatsandDogs/dataset/training_set')

# %%
filelist = []

for filename in filenames: 
    animal_class = filename.split('.')[0]
    if animal_class == 'dog': 
        filelist.append(1)
    else: 
        filelist.append(0)

# %%
animal_frame = pd.DataFrame({ 


    'filename':filenames,
    'category':filelist
})

# %%
animal_frame
# Out:
#           filename  category
# 0        cat.1.jpg         0
# 1       cat.10.jpg         0
# 2      cat.100.jpg         0
# 3     cat.1000.jpg         0
# 4     cat.1001.jpg         0
# ...            ...       ...
# 7995   dog.995.jpg         1
# 7996   dog.996.jpg         1
# 7997   dog.997.jpg         1
# 7998   dog.998.jpg         1
# 7999   dog.999.jpg         1
#
# [8000 rows x 2 columns]

# %%
sns.factorplot(data=animal_frame,kind='count',x='category')

# %%
animal_frame['category'] = animal_frame['category'].replace({0:'cat',1:'dog'})

# %%
animal_frame['category'].value_counts()
# Out:
# dog    4000
# cat    4000
# Name: category, dtype: int64

# %%
from keras.preprocessing.image import ImageDataGenerator,load_img
import random
import numpy as np

# %%
sample = random.choice(filenames)

# %%
plt.figure(figsize=(16,16))

for i in range(0,15): 
    sample = random.choice(filenames)
    plt.subplot(5,3,i+1) 
    img = load_img('C:/Users/Lee Jong Ann/Desktop/dataset/CatsandDogs/dataset/training_set/' + sample,target_size=(224,224))
    plt.imshow(img)
