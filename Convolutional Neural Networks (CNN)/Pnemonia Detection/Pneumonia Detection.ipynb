# %%
import os 
import matplotlib.pyplot as plt 
import seaborn as sns 
import pandas as pd 
import numpy as np 
import random
import warnings 
warnings.filterwarnings('ignore')
import cv2

# %%
Normal = os.listdir('C:/Users/Lee Jong Ann/Desktop/dataset/Pneumonia/chest_xray/train/NORMAL')
Pneumonia = os.listdir('C:/Users/Lee Jong Ann/Desktop/dataset/Pneumonia/chest_xray/train/PNEUMONIA')

# %%
filename = []

for label1 in Normal: 
    category = label1.split('.')[0]
    filename.append(category)

# %%
category
# Out:
# 'NORMAL2-IM-1423-0001'

# %%
a1
# Out:
# 'NORMAL2'

# %%
Normal_df = pd.DataFrame({ 
    'filename':filename,
})

# %%
Normal_df
# Out:
#                   filename
# 0             IM-0115-0001
# 1             IM-0117-0001
# 2             IM-0119-0001
# 3             IM-0122-0001
# 4             IM-0125-0001
# ...                    ...
# 1336  NORMAL2-IM-1406-0001
# 1337  NORMAL2-IM-1412-0001
# 1338  NORMAL2-IM-1419-0001
# 1339  NORMAL2-IM-1422-0001
# 1340  NORMAL2-IM-1423-0001
#
# [1341 rows x 1 columns]

# %%
categories2 = []
filename = []
for label2 in Pneumonia: 
    category2 = label2.split('.')[0]
    filename.append(category2)
    a2 = category2.split('_')
    if a2[1] == 'bacteria': 
        categories2.append(1)
    else: 
        categories2.append(0)

# %%
category2
# Out:
# 'person9_bacteria_41'

# %%
a2
# Out:
# ['person9', 'bacteria', '41']

# %%
Pneumonia_df = pd.DataFrame({ 

    'filename': filename,
    'category': categories2})

# %%
Pneumonia_df
# Out:
#                       filename  category
# 0     person1000_bacteria_2931         1
# 1        person1000_virus_1681         0
# 2     person1001_bacteria_2932         1
# 3     person1002_bacteria_2933         1
# 4     person1003_bacteria_2934         1
# ...                        ...       ...
# 3870        person99_virus_183         0
# 3871       person9_bacteria_38         1
# 3872       person9_bacteria_39         1
# 3873       person9_bacteria_40         1
# 3874       person9_bacteria_41         1
#
# [3875 rows x 2 columns]

# %%
import cv2
import random 
import numpy as np 
from keras.preprocessing.image import ImageDataGenerator,load_img

# %% [markdown]
# # Normal lung example (Healthy People)

# %%
fig,ax = plt.subplots(5,3)
fig.set_size_inches(16,16)

    
for i in range(0,15):
    plt.subplot(5,3,i+1)
    sample = random.choice(Normal)
    img = load_img('C:/Users/Lee Jong Ann/Desktop/dataset/Pneumonia/chest_xray/train/NORMAL/'+ sample,target_size=(224,224))
    plt.imshow(img)
    
plt.tight_layout()
